# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np



def optimize_inventory(input_df):

    df = input_df.copy()
   
    np.random.seed(42)
    df['demand'] = np.random.randint(5, 15, size=len(df))
    print(df['demand'])
    reorder_level = df['demand'].max()  # Set reorder level to the maximum demand for simplicity
    df['reorder_level'] = reorder_level
    df['reorder_quantity'] = df['reorder_level'] - df['stock']
    print("Medications Information:")
    print(df[['id', 'name', 'stock', 'demand', 'reorder_level', 'reorder_quantity']])

    return df[['id', 'name', 'stock', 'reorder_quantity']]


df = pd.read_csv('C:\\Users\\PRARTHANA T\\Downloads\\products (2).csv')
df
# Out:
#    id                      name  \
# 0  11                 Letrozole
# 1  12                Ranitidine
# 2  13  Polyethylene glycol 3350
# 3  14     Ambroxol Hydrochloric
# 4  15                  Cefdinir
# 5  16               Doxycycline
#
#                                              details  price     image  stock
# 0  Letrozole lowers estrogen levels in postmenopa...     54  img1.jpg     55
# 1  Ranitidine belongs to a group of drugs called ...     66  img2.jpg     84
# 2  Polyethylene glycol 3350 is a laxative solutio...     45  img3.jpg     37
# 3  Ambroxol works to thin down and break up phleg...     22   img.jpg     45
# 4  Cefdinir is a cephalosporin (SEF a low spor in...     33  img4.jpg     56
# 5  Doxycycline is a tetracycline antibiotic that ...     27  img5.jpg     32

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def content_optimization(df):
    vectorizer = TfidfVectorizer(stop_words='english')
    details_matrix = vectorizer.fit_transform(df['details'])
    similarity_matrix = cosine_similarity(details_matrix, details_matrix)
    result_df = pd.DataFrame(similarity_matrix, columns=df['name'], index=df['name'])
    return  result_df


df = pd.read_csv('C:\\Users\\PRARTHANA T\\Downloads\\products (2).csv')
content_optimization= content_optimization(df)
content_optimization
# Out:
# name                      Letrozole  Ranitidine  Polyethylene glycol 3350  \
# name
# Letrozole                  1.000000    0.006962                  0.005727
# Ranitidine                 0.006962    1.000000                  0.041149
# Polyethylene glycol 3350   0.005727    0.041149                  1.000000
# Ambroxol Hydrochloric      0.006909    0.048846                  0.026104
# Cefdinir                   0.039723    0.064685                  0.135314
# Doxycycline                0.027947    0.077615                  0.050339
#
# name                      Ambroxol Hydrochloric  Cefdinir  Doxycycline
# name
# Letrozole                              0.006909  0.039723     0.027947
# Ranitidine                             0.048846  0.064685     0.077615
# Polyethylene glycol 3350               0.026104  0.135314     0.050339
# Ambroxol Hydrochloric                  1.000000  0.041035     0.044438
# Cefdinir                               0.041035  1.000000     0.200833
# ...
