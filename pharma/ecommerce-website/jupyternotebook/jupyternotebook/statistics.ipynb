# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("C:\\Users\\PRARTHANA T\\Downloads\\products.csv")

price_statistics = df['price'].describe()
print("Basic Statistics for 'price' column:")
print(price_statistics)

#Histogram ofprices
plt.hist(df['price'], bins=20, edgecolor='black')
plt.title('Distribution of Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()
# Out:
# Basic Statistics for 'price' column:
# count     3.000000
# mean     27.333333
# std       5.507571
# min      22.000000
# 25%      24.500000
# 50%      27.000000
# 75%      30.000000
# max      33.000000
# Name: price, dtype: float64
